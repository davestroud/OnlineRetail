# %% [markdown]
# ### Exploring Clustering with Online Retail data from UCI
# MSDS 7331 Data Mining Lab 3
#
# Authors: Laura Ludwig, Anthony Schams, Josh Balson, David Stroud
#
# This is a trans-national data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# The selection of attributes plays an important role in good clustering analysis. Therefore, we will cluster the RPM (Recency, Frequency, Monetary) variables using the Online Retail Data Set from the UCI Machine Learning Repository.
#
# RPM analysis has historically been used to analyze large retail data sets of customer purchases to analyze retailer business activity. To accomplish this task, we will use clustering techniques to identify segments in the purchasing patterns to identify common characteristics. Since our data set is primarily composed of retailers purchasing from a wholesaler, it is in our best interest to identify the retailers purchasing patterns.
#
# Market segmentation allows a business to analyze, understand and draw good market segements from the customers purchasing behavior. Clustering analysis will allow us to identify segments of retail purchases who have certain characteristics. Idenfication of these paterns give us an information advantage, thus allowing us to act on better solutions for our clients.
#
# Once the data set has been properly cleaned, clustering intends to identify whether customers can be segmented meaningfully in the view of recency, frequency and monetary values. The k-means clustering algorithm was employed specifically for this purpose.
#
# ### Attribute Information:
#  - InvoiceNo: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
#  - StockCode: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.
#  - Description: Product (item) name. Nominal.
#  - Quantity: The quantities of each product (item) per transaction. Numeric.
#  - InvoiceDate: Invice Date and time. Numeric, the day and time when each transaction was generated.
# UnitPrice: Unit price. Numeric, Product price per unit in sterling.
#  - CustomerID: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.
#  - Country: Country name. Nominal, the name of the country where each customer res

# %%
import pandas as pd
import numpy as np

import time, warnings
import datetime as dt

#modules for predictive models
import sklearn.cluster as cluster
from sklearn.cluster import KMeans, SpectralClustering, AgglomerativeClustering
from sklearn.decomposition import PCA
from sklearn.mixture import GMM
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score

#visualizations
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# %matplotlib inline
import seaborn as sns
import matplotlib.patches as mpatches

warnings.filterwarnings("ignore")

# %%
#df = pd.read_excel('OnlineRetail.xlsx')
df = pd.read_csv('OnlineRetail.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
# Note that we have more than 540,000 instances
# and eight variables with the original dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null object
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# Remove all of the cancelled orders
# df = df.loc[(~df['InvoiceNo'].str.startswith('C'))] 
# Commenting out because do do this differently later in the Missing Data section

# %%
# We go from approximately 541,000 orders to 
# 532,000 orders, when we account for
# cancellations
# df.info()

# %% [markdown]
# RFM Score Calculations:
#  - RECENCY (R): Days since last purchase
#  - FREQUENCY (F): Total number of purchases
#  - MONETARY VALUE (M): Total money this customer spent
#
# The purpose of uing the RFM analysis is to reduce the data set into attributes that may explain the business activities of the retailers.

# %%
# Note that we have 38 unique countries in date set# 
df.Country.nunique()
# Out:
# 38

# %%
# Breakdown of each unique country
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
# We have a total of 4,339 customer id's ~ 3,921 are from the United Kingdom
df.CustomerID.nunique()
# Out:
# 4372

# %%
# List of Countries, by CustomerID in ascending order# List o 
customer_country=df[['Country','CustomerID']].drop_duplicates()
customer_country.groupby(['Country'])['CustomerID'].aggregate('count').reset_index().sort_values('CustomerID', ascending=False)
# Out:
#                  Country  CustomerID
# 36        United Kingdom        3950
# 14               Germany          95
# 13                France          87
# 31                 Spain          31
# 3                Belgium          25
# 33           Switzerland          21
# 27              Portugal          19
# 19                 Italy          15
# 12               Finland          12
# 1                Austria          11
# 25                Norway          10
# 24           Netherlands           9
# 0              Australia           9
# 6        Channel Islands           9
# 9                Denmark           9
# 7                 Cyprus           8
# 32                Sweden           8
# 20                 Japan           8
# 26                Poland           6
# 34                   USA           4
# 5                 Canada           4
# 37           Unspecified           4
# 18                Israel           4
# 15                Greece           4
# 10                  EIRE           3
# 23                 Malta           2
# 35  United Arab Emirates           2
# 2                Bahrain           2
# 22             Lithuania           1
# 8         Czech Republic           1
# 21               Lebanon           1
# 28                   RSA           1
# 29          Saudi Arabia           1
# 30             Singapore           1
# 17               Iceland           1
# 4                 Brazil           1
# 11    European Community           1
# 16             Hong Kong           0

# %% [markdown]
# More than 90% of the customers are from the United Kingdom

# %%
# Restrict data set to the United Kingdom only# 
df = df.loc[df['Country'] == 'United Kingdom']

# %% [markdown]
# ### Missing Data
# Notice that 133,277 values are missing from CustomerID. Since the analysis is based on customers, we will remove those with missing values. Thus, we are eliminating approximately twenty-five percent of the data set.
#
# We are now down to 408,632 of the original 541,909 values

# %%
# Check whether there are missing values in each column
df.isnull().sum(axis=0)
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133600
# Country             0
# dtype: int64

# %%
df = df[pd.notnull(df['CustomerID'])]

# %%
df.Quantity.min()
# Out:
# -80995

# %%
df.Quantity.plot(kind='box')

# %%
df.loc[df['Quantity'].apply(pd.to_numeric, errors='coerce').abs()>60000]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 61619     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624    C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 540421    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
# 540422   C581484     23843     PAPER CRAFT , LITTLE BIRDIE    -80995
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 61619   1/18/11 10:01       1.04     12346.0  United Kingdom
# 61624   1/18/11 10:17       1.04     12346.0  United Kingdom
# 540421   12/9/11 9:15       2.08     16446.0  United Kingdom
# 540422   12/9/11 9:27       2.08     16446.0  United Kingdom

# %%
# Create two dataframes that represent the positive transactions and negative (cancellation) transactions separately so we can combine them# Create 
df_pos = df.loc[df['Quantity']>0]
df_neg = df.loc[df['Quantity']<0]
df_neg.loc[:, 'Quantity'] = df_neg['Quantity'] * -1

# This takes all of the transactions that are positive, and matches them with any negative transactions in a new set of columns.
df_t = df_pos.merge(df_neg, how = 'left', on=['StockCode','Quantity','CustomerID'])

# %%
# This takes just the rows where there is a transaction and no corresponding cancellation (as best as we can find)
df_t1 = df_t.loc[df_t['InvoiceNo_y'].isnull()]
df_t2 = df_t1.iloc[:,0:8]
df_t2.columns = df.columns
df_t2.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  349809.000000  349809.000000  349809.000000
# mean       11.455074       2.879932   15550.102433
# std        45.575768       8.295879    1594.121433
# min         1.000000       0.000000   12747.000000
# 25%         2.000000       1.250000   14194.000000
# 50%         4.000000       1.850000   15524.000000
# 75%        12.000000       3.750000   16931.000000
# max     12540.000000    2033.100000   18287.000000

# %%
# There are no more negative quantities, and we have the resulting shape. 
df = df_t2
df.shape
# Out:
# (349809, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349809 entries, 0 to 354722
# Data columns (total 8 columns):
# InvoiceNo      349809 non-null object
# StockCode      349809 non-null object
# Description    349809 non-null object
# Quantity       349809 non-null int64
# InvoiceDate    349809 non-null object
# UnitPrice      349809 non-null float64
# CustomerID     349809 non-null float64
# Country        349809 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 24.0+ MB

# %% [markdown]
# The remaining dataset, having removed the orders that were cancelled and the cancelations, have 349,809 order line entries with eight different variables.

# %%
# Check the unique values for each column
def unique_counts(df):
    for i in df.columns:
        count = df[i].nunique()
        print(i, ":", count)
unique_counts(df)
# Out:
# InvoiceNo : 16424
# StockCode : 3639
# Description : 3835
# Quantity : 282
# InvoiceDate : 15412
# UnitPrice : 387
# CustomerID : 3910
# Country : 1

# %%
# add a column for total price
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %%
# We now have a clean data set and are ready to 
# proceed with placing the data in RPM format
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349809 entries, 0 to 354722
# Data columns (total 9 columns):
# InvoiceNo      349809 non-null object
# StockCode      349809 non-null object
# Description    349809 non-null object
# Quantity       349809 non-null int64
# InvoiceDate    349809 non-null object
# UnitPrice      349809 non-null float64
# CustomerID     349809 non-null float64
# Country        349809 non-null object
# TotalPrice     349809 non-null float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 26.7+ MB

# %% [markdown]
# ## Feature Engineering
#
# When you use domain knowledge to choose which data metrics to use as input features into a machine learning algorithm, you are using feature engineering. Feature engineering plays a key role in k-means clustering by capturing the variability of the data that is essential for the algorithm to find all of the natural-occurring groups.

# %% [markdown]
# ### Structure data set according to RFM analysis

# %%
# Find the first and last order dates in the data# Find t 
# to satisfy the Frequency requirements
df['InvoiceDate'].min() # min date
# Out:
# '1/10/11 10:32'

# %%
df['InvoiceDate'].max() # max date
# Out:
# '9/9/11 9:52'

# %%
# In order to create the frequency table, a point in time
# must be calculated. Since the last invoice date is 2011-12-09
# we will use 2011-12-10 to calculate Recency
import datetime as dt
NOW = dt.datetime(2011,12,10)

df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
# Create RFM table
rfmTable = df.groupby('CustomerID').agg({'InvoiceDate': lambda x:
                                        (NOW - x.max()).days,
                                        'InvoiceNo': lambda x: x.nunique(),
                                        'TotalPrice': lambda x: x.sum()})
rfmTable['AverageOrderSize']= rfmTable['TotalPrice']/rfmTable['InvoiceNo']

rfmTable['InvoiceDate'] = rfmTable['InvoiceDate'].astype(int)
rfmTable.rename(columns={'InvoiceDate': 'recency',
                        'InvoiceNo': 'frequency',
                        'TotalPrice': 'monetary_value',
                        'AverageOrderSize': 'average_order'},
               inplace=True)

# %%
rfmTable.head()
# Out:
#             recency  frequency  monetary_value  average_order
# CustomerID
# 12747.0           2         11         4196.01     381.455455
# 12748.0           0        202        30559.46     151.284455
# 12749.0           3          5         4090.88     818.176000
# 12820.0           3          4          942.34     235.585000
# 12821.0         214          1           92.72      92.720000

# %% [markdown]
# #### Translation:
# Customer 12747.0 has a Frequency:11, Monetary value of $4,196.01 and Recency of 2 days. This customer has made several purchases and their last purchase was two days before the end of the period of interest.
#
# Customer 12821.0 has a Frequency 1 , Monetary value of $92.72 and Recency of 214 days. The customer has made only one transaction, and it was 214 days ago.

# %%
# Sample viewing of a customer
#sample_customer = rfmTable[rfmTable['recency']==214]
#sample_customer

# %%
# Look at box plots of variables
plt.figure(figsize = (15,10))
plt.subplot(221)
rfmTable.recency.plot(kind='box')
plt.ylabel('Recency')
plt.subplot(222)
rfmTable.frequency.plot(kind='box')
plt.ylabel('Frequency')
plt.subplot(223)
rfmTable.monetary_value.plot(kind='box')
plt.ylabel('Monetary Value')
plt.subplot(224)
rfmTable.average_order.plot(kind='box')
plt.ylabel('Average order')


plt.show()

# %%
# get the 80% of the monetary value
pareto_cutoff = rfmTable['monetary_value'].sum() * 0.8
print("The 80% of total revenue is: ",round(pareto_cutoff,2))
# Out:
# The 80% of total revenue is:  5430510.04

# %% [markdown]
# ### Create a customers rank table that ranks customers by how much they purchased¶

# %%
customers_rank  = rfmTable
# Create a new column that is the rank of the value of coverage in ascending order
customers_rank['Rank'] = customers_rank['monetary_value'].rank(ascending=0)
#customers_rank.drop('RevenueRank',axis=1,inplace=True)
customers_rank.head()
# Out:
#             recency  frequency  monetary_value  average_order    Rank
# CustomerID
# 12747.0           2         11         4196.01     381.455455   272.0
# 12748.0           0        202        30559.46     151.284455    22.0
# 12749.0           3          5         4090.88     818.176000   285.0
# 12820.0           3          4          942.34     235.585000  1489.0
# 12821.0         214          1           92.72      92.720000  3781.0

# %% [markdown]
# ### Top Customers
#  - Note, there is a total of 3,910 Customer ID's

# %%
customers_rank.sort_values('Rank',ascending=True)
# Out:
#             recency  frequency  monetary_value  average_order    Rank
# CustomerID
# 18102.0           0         60       259657.30    4327.621667     1.0
# 17450.0           8         45       189767.53    4217.056222     2.0
# 17511.0           2         30        77682.38    2589.412667     3.0
# 16684.0           4         27        65767.48    2435.832593     4.0
# 14096.0           4         17        65164.79    3833.222941     5.0
# 13694.0           3         48        61403.14    1279.232083     6.0
# 15311.0           0         90        58949.31     654.992333     7.0
# 13089.0           2         93        57573.28     619.067527     8.0
# 15061.0           3         48        54391.94    1133.165417     9.0
# 17949.0           1         38        52279.08    1375.765263    10.0
# 14298.0           8         44        51527.30    1171.075000    11.0
# 15769.0           7         24        50984.72    2124.363333    12.0
# 14088.0          10         13        50415.49    3878.114615    13.0
# 16029.0          38         55        43334.09     787.892545    14.0
# 12931.0          21         15        40209.52    2680.634667    15.0
# 17841.0           1        124        38320.99     309.040242    16.0
# 13798.0           1         57        36910.49     647.552456    17.0
# 16013.0           3         45        35423.60     787.191111    18.0
# 16422.0          17         50        34604.60     692.092000    19.0
# 15838.0          11         19        33643.08    1770.688421    20.0
# 17389.0           0         34        31347.98     921.999412    21.0
# 12748.0           0        202        30559.46     151.284455    22.0
# 13098.0           1         28        28882.44    1031.515714    23.0
# 13081.0          11         11        28218.13    2565.284545    24.0
# 13408.0           1         62        27952.04     450.839355    25.0
# 14680.0          25         16        27330.41    1708.150625    26.0
# 17857.0           4         23        26806.54    1165.501739    27.0
# 16333.0           7         22        26626.80    1210.309091    28.0
# 13777.0           0         33        25977.16     787.186667    29.0
# 16210.0           1         18        21086.30    1171.461111    30.0
# ...             ...        ...             ...            ...     ...
# 14589.0         371          1           39.75      39.750000  3881.0
# 12977.0         156          1           39.24      39.240000  3882.0
# 16659.0         189          1           39.12      39.120000  3883.0
# 18019.0          51          1           38.45      38.450000  3884.0
# 12855.0         372          1           38.10      38.100000  3885.0
# 16162.0         252          1           37.40      37.400000  3886.0
# 17816.0          36          4           36.56       9.140000  3887.0
# 15940.0         311          1           35.80      35.800000  3888.0
# 17831.0          33          1           35.40      35.400000  3890.0
# 16856.0          14          1           35.40      35.400000  3890.0
# 14576.0         372          1           35.40      35.400000  3890.0
# 15744.0          77          1           34.80      34.800000  3892.0
# 16765.0         294          1           34.00      34.000000  3893.0
# 17408.0         163          1           32.65      32.650000  3894.0
# 13120.0         238          1           30.60      30.600000  3895.0
# 15657.0          22          1           30.00      30.000000  3896.0
# 17102.0         261          1           25.50      25.500000  3897.0
# 16953.0          30          1           20.80      20.800000  3898.5
# 17986.0          56          1           20.80      20.800000  3898.5
# 18072.0         185          1           20.04      20.040000  3900.0
# 16093.0         106          1           17.00      17.000000  3901.0
# 15823.0         372          1           15.00      15.000000  3903.5
# 17900.0         190          1           15.00      15.000000  3903.5
# 13307.0         120          1           15.00      15.000000  3903.5
# 17763.0         263          1           15.00      15.000000  3903.5
# 17956.0         249          1           12.75      12.750000  3906.0
# 16454.0          64          1            5.90       5.900000  3907.0
# 16738.0         297          1            3.75       3.750000  3908.0
# 16446.0         205          1            2.90       2.900000  3909.0
# 13256.0          14          1            0.00       0.000000  3910.0
#
# [3910 rows x 5 columns]

# %%
# get the top 20% of customers
top_20percent = 3910 * 20 / 100
top_20percent
# Out:
# 782.0

# %%
# sum the monetary values over the customer with rank <=782

# %%
top_20percent_revenue = customers_rank[customers_rank['Rank'] <= 782]['monetary_value'].sum()
top_20percent_revenue
# Out:
# 4873025.921

# %% [markdown]
# Pareto principle is basically applicable to this data set
#
#  - The 80% of total revenue is 5430510.04
#  - Top 20% of 4873025.92
#
# ### RFM Quartiles
# We will create customer segments from the RFM model and assign a score from 1 to 4.

# %%
quantiles = rfmTable.quantile(q=[0.25,0.5,0.75])
quantiles
# Out:
#       recency  frequency  monetary_value  average_order     Rank
# 0.25     17.0        1.0        296.2625     172.908125   978.25
# 0.50     50.0        2.0        639.4550     278.971111  1955.50
# 0.75    143.0        5.0       1538.1225     407.323125  2932.75

# %%
# Convert the dataframe to a dictionary for 
# building the RFM segmentation table
quantiles.to_dict()
# Out:
# {'recency': {0.25: 17.0, 0.5: 50.0, 0.75: 143.0},
#  'frequency': {0.25: 1.0, 0.5: 2.0, 0.75: 5.0},
#  'monetary_value': {0.25: 296.2625, 0.5: 639.455, 0.75: 1538.1224999999997},
#  'average_order': {0.25: 172.908125,
#   0.5: 278.9711111111111,
#   0.75: 407.32312500000006},
#  'Rank': {0.25: 978.25, 0.5: 1955.5, 0.75: 2932.75}}

# %% [markdown]
# ### Create RFM segmentation table
# Two segmentation classes are created

# %%
# x = value, p = recency, monetary_value, frequency, d = quartiles dict
def RScore(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.5]:
        return 3
    elif x <= d[p][0.75]:
        return 2
    else:
        return 1

# %%
# x = value, p = recency, monetary_value, frequency, d = quartiles dict
def FMScore(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.5]:
        return 3
    elif x <= d[p][0.75]:
        return 2
    else:
        return 1

# %%
# create RFM segmentation table
rfm_segmentation = rfmTable
rfm_segmentation['R_Quartile'] = rfm_segmentation['recency'].apply(RScore, args=('recency', quantiles,))
rfm_segmentation['F_Quartile'] = rfm_segmentation['frequency'].apply(FMScore, args=('frequency', quantiles,))
rfm_segmentation['M_Quartile'] = rfm_segmentation['monetary_value'].apply(FMScore, args=('monetary_value', quantiles,))

# %%
# From our code above, we have transformed the recency, frequency and montetary_value
# into four distinct quartiles 1 to 4 respectively representing 0 to 100%
rfm_segmentation.head()
# Out:
#             recency  frequency  monetary_value  average_order    Rank  \
# CustomerID
# 12747.0           2         11         4196.01     381.455455   272.0
# 12748.0           0        202        30559.46     151.284455    22.0
# 12749.0           3          5         4090.88     818.176000   285.0
# 12820.0           3          4          942.34     235.585000  1489.0
# 12821.0         214          1           92.72      92.720000  3781.0
#
#             R_Quartile  F_Quartile  M_Quartile
# CustomerID
# 12747.0              4           1           1
# 12748.0              4           1           1
# 12749.0              4           2           1
# 12820.0              4           2           2
# 12821.0              1           4           4

# %%
rfm_segmentation['RFMScore'] = rfm_segmentation.R_Quartile.map(str) \
                            + rfm_segmentation.F_Quartile.map(str) \
                            + rfm_segmentation.M_Quartile.map(str)
rfm_segmentation.head()
# Out:
#             recency  frequency  monetary_value  average_order    Rank  \
# CustomerID
# 12747.0           2         11         4196.01     381.455455   272.0
# 12748.0           0        202        30559.46     151.284455    22.0
# 12749.0           3          5         4090.88     818.176000   285.0
# 12820.0           3          4          942.34     235.585000  1489.0
# 12821.0         214          1           92.72      92.720000  3781.0
#
#             R_Quartile  F_Quartile  M_Quartile RFMScore
# CustomerID
# 12747.0              4           1           1      411
# 12748.0              4           1           1      411
# 12749.0              4           2           1      421
# 12820.0              4           2           2      422
# 12821.0              1           4           4      144

# %%
rfm_segmentation[rfm_segmentation['RFMScore']=='444'].sort_values('monetary_value', ascending=False).head(10)
# Out:
#             recency  frequency  monetary_value  average_order    Rank  \
# CustomerID
# 17247.0          15          1          282.19         282.19  2981.0
# 14480.0          11          1          279.05         279.05  2993.0
# 17767.0          15          1          271.20         271.20  3013.0
# 17385.0          14          1          261.11         261.11  3046.0
# 16024.0          12          1          251.24         251.24  3082.0
# 15097.0           4          1          248.08         248.08  3097.0
# 13349.0          10          1          247.32         247.32  3100.0
# 15783.0          10          1          246.30         246.30  3103.0
# 16528.0           3          1          244.41         244.41  3110.0
# 15634.0          17          1          243.55         243.55  3117.0
#
#             R_Quartile  F_Quartile  M_Quartile RFMScore
# CustomerID
# 17247.0              4           4           4      444
# 14480.0              4           4           4      444
# 17767.0              4           4           4      444
# 17385.0              4           4           4      444
# 16024.0              4           4           4      444
# 15097.0              4           4           4      444
# 13349.0              4           4           4      444
# 15783.0              4           4           4      444
# 16528.0              4           4           4      444
# 15634.0              4           4           4      444

# %%
print("Best Customers: ",len(rfm_segmentation[rfm_segmentation['RFMScore']=='444']))
print('Loyal Customers: ',len(rfm_segmentation[rfm_segmentation['F_Quartile']==4]))
print("Big Spenders: ",len(rfm_segmentation[rfm_segmentation['M_Quartile']==4]))
print('Almost Lost: ', len(rfm_segmentation[rfm_segmentation['RFMScore']=='244']))
print('Lost Customers: ',len(rfm_segmentation[rfm_segmentation['RFMScore']=='144']))
print('Lost Cheap Customers: ',len(rfm_segmentation[rfm_segmentation['RFMScore']=='111']))
# Out:
# Best Customers:  55
# Loyal Customers:  1353
# Big Spenders:  978
# Almost Lost:  184
# Lost Customers:  400
# Lost Cheap Customers:  12

# %%
rfm_data = rfmTable
rfm_data.describe()
# Out:
#            recency    frequency  monetary_value  average_order         Rank  \
# count  3910.000000  3910.000000     3910.000000    3910.000000  3910.000000
# mean     92.046547     4.200512     1736.096561     343.800542  1955.500000
# std      99.803816     7.064531     6601.251333     317.679319  1128.864101
# min       0.000000     1.000000        0.000000       0.000000     1.000000
# 25%      17.000000     1.000000      296.262500     172.908125   978.250000
# 50%      50.000000     2.000000      639.455000     278.971111  1955.500000
# 75%     143.000000     5.000000     1538.122500     407.323125  2932.750000
# max     373.000000   202.000000   259657.300000    4327.621667  3910.000000
#
#         R_Quartile   F_Quartile   M_Quartile
# count  3910.000000  3910.000000  3910.000000
# mean      2.508696     2.684399     2.500000
# std       1.123621     1.142960     1.118406
# min       1.000000     1.000000     1.000000
# 25%       2.000000     2.000000     1.250000
# 50%       3.000000     3.000000     2.500000
# 75%       4.000000     4.000000     3.750000
# max       4.000000     4.000000     4.000000

# %%
#log transformation
rfm_r_log = np.log(rfm_data['recency']+1) #can't take log(0) and so add 1 to avoid negative values
rfm_f_log = np.log(rfm_data['frequency'])
rfm_m_log = np.log(rfm_data['monetary_value']+1)
rfm_a_log = np.log(rfm_data['average_order']+1)

# %%
log_data = pd.DataFrame({'Monetary': rfm_m_log,'Recency': rfm_r_log,'Frequency': rfm_f_log,'AverageOrder': rfm_a_log})

# %%
log_data.describe()
# Out:
#        AverageOrder    Frequency     Monetary      Recency
# count   3910.000000  3910.000000  3910.000000  3910.000000
# mean       5.590189     0.938794     6.526994     3.801249
# std        0.709402     0.896210     1.236157     1.383083
# min        0.000000     0.000000     0.000000     0.000000
# 25%        5.158527     0.000000     5.694616     2.890372
# 50%        5.634686     0.693147     6.462179     3.931826
# 75%        6.012059     1.609438     7.338968     4.969813
# max        8.373004     5.308268    12.467122     5.924256

# %%
import seaborn as sns

sns.pairplot(log_data)

# %%
corr = log_data.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row0_col0 {
#             background-color:  #023858;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row0_col1 {
#             background-color:  #7dacd1;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row0_col2 {
#             background-color:  #0567a2;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row0_col3 {
#             background-color:  #c8cde4;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row1_col0 {
#             background-color:  #c8cde4;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row1_col1 {
#             background-color:  #023858;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row1_col2 {
#             background-color:  #04588a;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row1_col3 {
#             background-color:  #fff7fb;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row2_col0 {
#             background-color:  #0a73b2;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row2_col1 {
#             background-color:  #045687;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row2_col2 {
#             background-color:  #023858;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row2_col3 {
#             background-color:  #f8f1f8;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row3_col0 {
#             background-color:  #fff7fb;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row3_col1 {
#             background-color:  #fff7fb;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row3_col2 {
#             background-color:  #fff7fb;
#         }    #T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row3_col3 {
#             background-color:  #023858;
#         }</style>
# <table id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >AverageOrder</th>
#         <th class="col_heading level0 col1" >Frequency</th>
#         <th class="col_heading level0 col2" >Monetary</th>
#         <th class="col_heading level0 col3" >Recency</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2level0_row0" class="row_heading level0 row0" >AverageOrder</th>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row0_col0" class="data row0 col0" >1</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row0_col1" class="data row0 col1" >0.174811</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row0_col2" class="data row0 col2" >0.701491</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row0_col3" class="data row0 col3" >-0.140014</td>
#     </tr>    <tr>
#         <th id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2level0_row1" class="row_heading level0 row1" >Frequency</th>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row1_col0" class="data row1 col0" >0.174811</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row1_col1" class="data row1 col1" >1</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row1_col2" class="data row1 col2" >0.824331</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row1_col3" class="data row1 col3" >-0.576748</td>
#     </tr>    <tr>
#         <th id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2level0_row2" class="row_heading level0 row2" >Monetary</th>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row2_col0" class="data row2 col0" >0.701491</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row2_col1" class="data row2 col1" >0.824331</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row2_col2" class="data row2 col2" >1</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row2_col3" class="data row2 col3" >-0.498009</td>
#     </tr>    <tr>
#         <th id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2level0_row3" class="row_heading level0 row3" >Recency</th>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row3_col0" class="data row3 col0" >-0.140014</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row3_col1" class="data row3 col1" >-0.576748</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row3_col2" class="data row3 col2" >-0.498009</td>
#         <td id="T_4887c8c2_9dcc_11e8_8f6b_8c85900771e2row3_col3" class="data row3 col3" >1</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### Ready to begin cluster analysis

# %%
from sklearn.cluster import MiniBatchKMeans


X1 = log_data[['Frequency','Recency', 'Monetary']]

# %%
# run kmeans algorithm (this is the most traditional use of k-means)
kmeans = KMeans(init='random', # initialization
        n_clusters=8,  # number of clusters
        n_init=1,       # number of different times to run k-means
        n_jobs=-1)
kmeans_mini = MiniBatchKMeans(n_clusters=8, batch_size=10)

kmeans.fit(X1)
kmeans_mini.fit(X1)
# Out:
# MiniBatchKMeans(batch_size=10, compute_labels=True, init='k-means++',
#         init_size=None, max_iter=100, max_no_improvement=10, n_clusters=8,
#         n_init=3, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)

# %%
# visualize the data
centroids = kmeans.cluster_centers_
plt.plot(X1.iloc[:, 0], X1.iloc[:, 2], 'r.', markersize=2) #plot the data
plt.scatter(centroids[:, 0], centroids[:, 2],
            marker='+', s=200, linewidths=3, label='Batch')  # plot the centroids

centroids = kmeans_mini.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 2],
            marker='+', s=200, linewidths=3, color='k',label='Mini-Batch')  # plot the centroids
plt.legend()
plt.title('K-means clustering for X1')
plt.xlabel('Frequency')
plt.ylabel('Monetary')
plt.grid()
plt.show()

# %%
matrix = X1.as_matrix()
for n_clusters in range(2,20):
    kmeans = KMeans(init='k-means++', n_clusters = n_clusters, n_init=100)
    kmeans.fit(matrix)
    clusters = kmeans.predict(matrix)
    silhouette_avg = silhouette_score(matrix, clusters)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.42048369349482084
# For n_clusters = 3 The average silhouette_score is : 0.3295297895684317
# For n_clusters = 4 The average silhouette_score is : 0.3462868530284631
# For n_clusters = 5 The average silhouette_score is : 0.3282759172860545
# For n_clusters = 6 The average silhouette_score is : 0.31879937108948975
# For n_clusters = 7 The average silhouette_score is : 0.3118252416827617
# For n_clusters = 8 The average silhouette_score is : 0.31597127807691716
# For n_clusters = 9 The average silhouette_score is : 0.29568537140203455
# For n_clusters = 10 The average silhouette_score is : 0.2939760686267765
# For n_clusters = 11 The average silhouette_score is : 0.2873631286760025
# For n_clusters = 12 The average silhouette_score is : 0.28660884329825986
# For n_clusters = 13 The average silhouette_score is : 0.2841528900644174
# For n_clusters = 14 The average silhouette_score is : 0.2799816401761259
# For n_clusters = 15 The average silhouette_score is : 0.28054208100672234
# For n_clusters = 16 The average silhouette_score is : 0.2828221191210949
# For n_clusters = 17 The average silhouette_score is : 0.2821670452214199
# For n_clusters = 18 The average silhouette_score is : 0.28554762084448104
# For n_clusters = 19 The average silhouette_score is : 0.2850308048925466

# %%
X2 = log_data[['Recency', 'Monetary']]

# run kmeans algorithm (this is the most traditional use of k-means)
kmeans2 = KMeans(init='random', # initialization
        n_clusters=8,  # number of clusters
        n_init=1,       # number of different times to run k-means
        n_jobs=-1)
kmeans_mini2 = MiniBatchKMeans(n_clusters=8, batch_size=10)

kmeans2.fit(X2)
kmeans_mini2.fit(X2)
# Out:
# MiniBatchKMeans(batch_size=10, compute_labels=True, init='k-means++',
#         init_size=None, max_iter=100, max_no_improvement=10, n_clusters=8,
#         n_init=3, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)

# %%
# visualize the data
centroids = kmeans2.cluster_centers_
plt.plot(X2.iloc[:, 0], X2.iloc[:, 1], 'r.', markersize=2) #plot the data
plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='+', s=200, linewidths=3, label='Batch')  # plot the centroids

centroids = kmeans_mini2.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='+', s=200, linewidths=3, color='k',label='Mini-Batch')  # plot the centroids
plt.legend()
plt.title('K-means clustering for X2')
plt.xlabel('Recency')
plt.ylabel('Monetary')
plt.grid()
plt.show()

# %%
matrix = X2.as_matrix()
for n_clusters in range(2,20):
    kmeans = KMeans(init='k-means++', n_clusters = n_clusters, n_init=100)
    kmeans.fit(matrix)
    clusters = kmeans.predict(matrix)
    silhouette_avg = silhouette_score(matrix, clusters)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.4233689526869893
# For n_clusters = 3 The average silhouette_score is : 0.35205839671400524
# For n_clusters = 4 The average silhouette_score is : 0.3699914531910366
# For n_clusters = 5 The average silhouette_score is : 0.3376756172813406
# For n_clusters = 6 The average silhouette_score is : 0.3456278828553534
# For n_clusters = 7 The average silhouette_score is : 0.33175060710390114
# For n_clusters = 8 The average silhouette_score is : 0.33506913348098055
# For n_clusters = 9 The average silhouette_score is : 0.3507855271647096
# For n_clusters = 10 The average silhouette_score is : 0.34845569298215867
# For n_clusters = 11 The average silhouette_score is : 0.3414000884041088
# For n_clusters = 12 The average silhouette_score is : 0.3480034460467283
# For n_clusters = 13 The average silhouette_score is : 0.3420302041556627
# For n_clusters = 14 The average silhouette_score is : 0.3391595086411647
# For n_clusters = 15 The average silhouette_score is : 0.3394100273153173
# For n_clusters = 16 The average silhouette_score is : 0.3386365574668819
# For n_clusters = 17 The average silhouette_score is : 0.33990827756976255
# For n_clusters = 18 The average silhouette_score is : 0.34062767883112477
# For n_clusters = 19 The average silhouette_score is : 0.33943823020302627

# %%
n_clusters = 2
kmeans = KMeans(init='k-means++', n_clusters = n_clusters, n_init=30)
kmeans.fit(matrix)
clusters_customers = kmeans.predict(matrix)
silhouette_avg = silhouette_score(matrix, clusters_customers)
print('silhouette Score: {:<.3f}'.format(silhouette_avg))
# Out:
# silhouette Score: 0.423

# %%
#create a scatter plot
plt.scatter(matrix[:, 0], matrix[:, 1], c=clusters_customers, s=50, cmap='viridis')
#select cluster centers
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
# What's the number of customers in each cluster?
pd.DataFrame(pd.Series(clusters_customers).value_counts(), columns = ['NumberCustomers']).T
# Out:
#                     0     1
# NumberCustomers  2215  1695

# %%
from matplotlib import pyplot as plt
plt.style.use("ggplot")

# %matplotlib inline
X1 = log_data[['Frequency','Recency','Monetary']].values

plt.scatter(X1[:, 1], X1[:, 0]+np.random.random(X1[:, 1].shape)/2, 
             s=8)
plt.xlabel('Recency'), plt.ylabel('Frequency')
plt.grid()
plt.title('Recency vs. Frequency')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.scatter(X1[:, 0], X1[:, 1])
plt.grid()
plt.subplot(1,2,2)
plt.plot(X1[:, 0], X1[:, 1], 'r.', markersize=2) #plot the data
plt.grid()

plt.show()

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
from matplotlib import pyplot as plt
plt.style.use("ggplot")

# %matplotlib inline
X1 = log_data[['Frequency','Recency']].values

plt.scatter(X1[:, 1], X1[:, 0]+np.random.random(X1[:, 1].shape)/2, 
             s=20)

plt.xlabel('Recency (normalized)'), plt.ylabel('Frequency')
plt.grid()
plt.title('Frequency vs Recency')
plt.show()

# %%
# get the first clustering
cls_fare = KMeans(n_clusters=8, init='k-means++',random_state=1)
cls_fare.fit(X1)
newfeature_fare = cls_fare.labels_ # the labels from kmeans clustering

# %%
# lets first look at the connectivity of the graphs and distance to the nearest neighbors
from sklearn.neighbors import kneighbors_graph

X1 = log_data
#=======================================================
# CHANGE THESE VALUES TO ADJUST MINPTS FOR EACH DATASET
X1_N =7
#=======================================================

# create connectivity graphs before calcualting the hierarchy
X1_knn_graph = kneighbors_graph(X1, X1_N, mode='distance') # calculate distance to four nearest neighbors 

N1 = X1_knn_graph.shape[0]
X1_4nn_distances = np.zeros((N1,1))
for i in range(N2):
    X1_4nn_distances[i] = X1_knn_graph[i,:].max()

X1_4nn_distances = np.sort(X1_4nn_distances, axis=0)


plt.figure(figsize=(15,5))
plt.plot(range(N1), X1_4nn_distances, 'r.', markersize=2) #plot the data
plt.title('Dataset name: X1, sorted by neighbor distance')
plt.xlabel('X1, Instance Number')
plt.ylabel('X1, Distance to {0}th nearest neighbor'.format(X1_N))
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-85ff279c2a03> in <module>()
#      13 N1 = X1_knn_graph.shape[0]
#      14 X1_4nn_distances = np.zeros((N1,1))
# ---> 15 for i in range(N2):
#      16     X1_4nn_distances[i] = X1_knn_graph[i,:].max()
#      17
#
# NameError: name 'N2' is not defined

# %% [markdown]
# eps is probably between 0.6 and 0.8. This estimate does not change for looking at different values of N (nearest neighbors).

# %%
from sklearn.cluster import DBSCAN

#=====================================
# ENTER YOUR CODE HERE TO CHANGE MINPTS AND EPS FOR EACH DATASET
X1_minpts = 8 # from above
X1_eps = 0.75

#=====================================

for i, (data, minpts, eps) in enumerate(zip([X1],[X1_minpts],[X1_eps])):

    db = DBSCAN(eps=eps, min_samples=minpts).fit(data)
    labels = db.labels_

    # Number of clusters in labels, ignoring noise if present.
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

    # mark the samples that are considered "core"
    core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
    core_samples_mask[db.core_sample_indices_] = True

    plt.figure(figsize=(10,10))
    unique_labels = set(labels) # the unique labels
    colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
    for k, col in zip(unique_labels, colors):
        if k == -1:
            # Black used for noise.
            col = 'k'

        class_member_mask = (labels == k)

        xy = data[class_member_mask & core_samples_mask]
        # plot the core points in this class
        plt.plot(xy.iloc[:, 1], xy.iloc[:,3 ], 'o', markerfacecolor=col,
                 markeredgecolor='w', markersize=6)

        # plot the remaining points that are edge points
       # xy = data[class_member_mask & ~core_samples_mask]
        #plt.plot(xy.iloc[:, 1], xy.iloc[:, 3], 'o', markerfacecolor=col,
              #   markeredgecolor='w', markersize=3)

    plt.title('Estimated number of clusters: %d' % n_clusters_)
    plt.xlabel('Frequency (log)')
    plt.ylabel('Recency (log)')
    plt.grid(True)
    plt.show()

# %% [markdown]
# As a reminder, Frequency is equivalent to the number of orders a customer has placed, and we have taken the log of these values.
# * In this clustering, there is a cluster along x=0, which is equivalent to customers have placed one order. Most of these customers have not ordered in the last week of our data set ((e^2.1)-1=~7).
# * The next cluster, along x=0.7, represents customers who have placed two orders, and most of these orders were also placed longer than a week ago.
# * The third cluster represents customers who have placed 3 or more orders, the latest of which was placed the day before the end of our study period.
# * The fourth cluster represents customers who have placed 14 or more orders, the latest of which was placed the day before the end of our study period.
# * The majority of customers fall into the largest cluster of customers who have made more than three orders, and their latest order was at least 2 days befor the end of our study period.

# %%
c = ['k','c','r','b','g']
for minpts in range(8,15):
    for eps in range(8,16):
        true_eps = eps /20
        clustering = DBSCAN(eps=true_eps, min_samples=minpts)
        clustering.fit(X1)
        clusters = clustering.labels_
        silhouette_avg = silhouette_score(anthony_data, clusters)
        print("For minpts =", minpts, 'eps =',true_eps," The average silhouette_score is :", silhouette_avg)
        plt.scatter(minpts,silhouette_avg)
# red_patch = mpatches.Patch(color='red', 
#                            label='eps = 3')
# cyan_patch = mpatches.Patch(color = 'c', label = 'eps = 2.5')
# blue_patch = mpatches.Patch(color='blue',
#                             label = 'eps = 3.5')
# black_patch = mpatches.Patch(color='black', 
#                              label = 'eps = 2')
# plt.legend(handles=[black_patch, cyan_patch, red_patch, blue_patch],
#            bbox_to_anchor=(1.05, 1),
#            loc=2)
# Out:
# For minpts = 8 eps = 0.4  The average silhouette_score is : -0.34664155783521583
# For minpts = 8 eps = 0.45  The average silhouette_score is : -0.34196356691951607
# For minpts = 8 eps = 0.5  The average silhouette_score is : -0.028542243434341467
# For minpts = 8 eps = 0.55  The average silhouette_score is : -0.33119946862588584
# For minpts = 8 eps = 0.6  The average silhouette_score is : -0.03345848166766933
# For minpts = 8 eps = 0.65  The average silhouette_score is : -0.02365666070593516
# For minpts = 8 eps = 0.7  The average silhouette_score is : -0.03228126528825714
# For minpts = 8 eps = 0.75  The average silhouette_score is : 0.05424815581252646
# For minpts = 9 eps = 0.4  The average silhouette_score is : -0.46111141251256965
# For minpts = 9 eps = 0.45  The average silhouette_score is : -0.08052632646194977
# For minpts = 9 eps = 0.5  The average silhouette_score is : -0.03334033143732704
# For minpts = 9 eps = 0.55  The average silhouette_score is : -0.01046735209302482
# For minpts = 9 eps = 0.6  The average silhouette_score is : -0.023271666743066282
# For minpts = 9 eps = 0.65  The average silhouette_score is : -0.009470082142911878
# For minpts = 9 eps = 0.7  The average silhouette_score is : -0.04321280467799275
# For minpts = 9 eps = 0.75  The average silhouette_score is : 0.036363743204202464
# For minpts = 10 eps = 0.4  The average silhouette_score is : -0.33557564571884296
# For minpts = 10 eps = 0.45  The average silhouette_score is : -0.08378028634567304
# For minpts = 10 eps = 0.5  The average silhouette_score is : -0.04479055574990967
# For minpts = 10 eps = 0.55  The average silhouette_score is : -0.02774872604318902
# For minpts = 10 eps = 0.6  The average silhouette_score is : -0.023659042516322913
# For minpts = 10 eps = 0.65  The average silhouette_score is : -0.03595143289528335
# For minpts = 10 eps = 0.7  The average silhouette_score is : -0.012443204143057825
# For minpts = 10 eps = 0.75  The average silhouette_score is : 0.05152897939597026
# For minpts = 11 eps = 0.4  The average silhouette_score is : -0.34641358542848044
# For minpts = 11 eps = 0.45  The average silhouette_score is : -0.3601182927033135
# For minpts = 11 eps = 0.5  The average silhouette_score is : -0.04952881828088838
# For minpts = 11 eps = 0.55  The average silhouette_score is : -0.043424442465209365
# For minpts = 11 eps = 0.6  The average silhouette_score is : -0.04621662595752759
# For minpts = 11 eps = 0.65  The average silhouette_score is : -0.04449080916142356
# For minpts = 11 eps = 0.7  The average silhouette_score is : -0.026210411557165733
# For minpts = 11 eps = 0.75  The average silhouette_score is : 0.016711345670188605
# For minpts = 12 eps = 0.4  The average silhouette_score is : -0.3448788741725725
# For minpts = 12 eps = 0.45  The average silhouette_score is : -0.08555492572480737
# For minpts = 12 eps = 0.5  The average silhouette_score is : -0.049465620620055155
# For minpts = 12 eps = 0.55  The average silhouette_score is : -0.049133932295516165
# For minpts = 12 eps = 0.6  The average silhouette_score is : -0.041445811369481306
# For minpts = 12 eps = 0.65  The average silhouette_score is : -0.04523459872263802
# For minpts = 12 eps = 0.7  The average silhouette_score is : -0.027441125347809542
# For minpts = 12 eps = 0.75  The average silhouette_score is : -0.0009124234284525153
# For minpts = 13 eps = 0.4  The average silhouette_score is : -0.36254795600334977
# For minpts = 13 eps = 0.45  The average silhouette_score is : -0.08369737561666143
# For minpts = 13 eps = 0.5  The average silhouette_score is : -0.053624388801516605
# For minpts = 13 eps = 0.55  The average silhouette_score is : -0.05619489661819157
# For minpts = 13 eps = 0.6  The average silhouette_score is : -0.039400072858720776
# For minpts = 13 eps = 0.65  The average silhouette_score is : -0.048451652954892385
# For minpts = 13 eps = 0.7  The average silhouette_score is : -0.03000138890428493
# For minpts = 13 eps = 0.75  The average silhouette_score is : -0.026270193902239083
# For minpts = 14 eps = 0.4  The average silhouette_score is : -0.3671498165965142
# For minpts = 14 eps = 0.45  The average silhouette_score is : -0.0679830436815971
# For minpts = 14 eps = 0.5  The average silhouette_score is : -0.058114145540412915
# For minpts = 14 eps = 0.55  The average silhouette_score is : -0.06686585843381436
# For minpts = 14 eps = 0.6  The average silhouette_score is : -0.04281539131083806
# For minpts = 14 eps = 0.65  The average silhouette_score is : -0.04792693761857626
# For minpts = 14 eps = 0.7  The average silhouette_score is : -0.03593713719142692
# For minpts = 14 eps = 0.75  The average silhouette_score is : -0.022775185714093805

# %%
km = KMeans(init='k-means++',    # initialization
               n_clusters=15,    # number of clusters
               n_init=11,         # number of different times to run k-means
               n_jobs=-1)

# %%
from mpl_toolkits.mplot3d import Axes3D

as_data= log_data[['Frequency','Recency','Monetary']].values
as_rfm = rfm_data[['frequency', 'recency', 'monetary_value']].values

anthony_data = np.vstack((as_data[:,0],
               as_rfm[:, 1],
               as_data[:,2])).T
ss = StandardScaler()
anthony_data = ss.fit_transform(anthony_data)
km.fit(anthony_data)

fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
p = ax.scatter(anthony_data[:,0],
               anthony_data[:, 1],
               anthony_data[:,2],
              alpha = 0.1)

km_centroids = km.cluster_centers_
p2 = ax.scatter(km_centroids[:,0],
                km_centroids[:,1],
                km_centroids[:,2],
                c='k',
                s = 100,
                marker = '+')
ax.set_xlim3d(-1,3)
ax.set_ylim3d(-1,2)
ax.set_zlim3d(-4,4)
# Out:
# (-4, 4)

# %%
#anthony_matrix= anthony_data.as_matrix()
for n_clusters in range(2,20):
    kmeans = KMeans(init='k-means++', n_clusters = n_clusters, n_init=100)
    kmeans.fit(anthony_data)
    clusters = kmeans.predict(anthony_data)
    silhouette_avg = silhouette_score(anthony_data, clusters)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)
    plt.scatter(n_clusters,silhouette_avg, c='k')
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.4154611174978883
# For n_clusters = 3 The average silhouette_score is : 0.4095887952232401
# For n_clusters = 4 The average silhouette_score is : 0.3766458607420354
# For n_clusters = 5 The average silhouette_score is : 0.34489916855234687
# For n_clusters = 6 The average silhouette_score is : 0.3425163434267329
# For n_clusters = 7 The average silhouette_score is : 0.33340922483371066
# For n_clusters = 8 The average silhouette_score is : 0.30736996847782055
# For n_clusters = 9 The average silhouette_score is : 0.3093987772720297
# For n_clusters = 10 The average silhouette_score is : 0.30603144536422516
# For n_clusters = 11 The average silhouette_score is : 0.2928725954622718
# For n_clusters = 12 The average silhouette_score is : 0.297956912653406
# For n_clusters = 13 The average silhouette_score is : 0.2993550018477972
# For n_clusters = 14 The average silhouette_score is : 0.3018616071114144
# For n_clusters = 15 The average silhouette_score is : 0.3079231536940127
# For n_clusters = 16 The average silhouette_score is : 0.3003040581741048
# For n_clusters = 17 The average silhouette_score is : 0.29920233937584967
# For n_clusters = 18 The average silhouette_score is : 0.2992515107435252
# For n_clusters = 19 The average silhouette_score is : 0.3013722319210959

# %% [markdown]
# ### DBSCAN

# %%
c = ['k','c','r','b','g','y']
for minpts in range(8,15):
    for eps in range(10,16):
        true_eps = eps/20
        clustering = DBSCAN(eps=true_eps, min_samples=minpts)
        clustering.fit(anthony_data)
        clusters = clustering.labels_
        silhouette_avg = silhouette_score(anthony_data, clusters)
        print("For minpts =", minpts, 'eps =',true_eps," The average silhouette_score is :", silhouette_avg)
        plt.scatter(minpts,silhouette_avg, c=c[eps-10])
red_patch = mpatches.Patch(color='red', 
                           label='eps = 0.6')
cyan_patch = mpatches.Patch(color = 'c', label = 'eps = 0.55')
blue_patch = mpatches.Patch(color='blue',
                            label = 'eps = 0.65')
black_patch = mpatches.Patch(color='black', 
                             label = 'eps = 0.5')
green_patch = mpatches.Patch(color='g',
                            label = 'eps = 0.7')
yellow_patch = mpatches.Patch(color = 'y', 
                             label = 'eps= 0.75')
plt.legend(handles=[black_patch, cyan_patch, red_patch, blue_patch, green_patch, yellow_patch],
           bbox_to_anchor=(1.05, 1),
           loc=2)

plt.xlabel('minpts')
plt.ylabel('eps')
plt.title('Silhouette Score ')
# Out:
# For minpts = 8 eps = 0.5  The average silhouette_score is : 0.3477467131270432
# For minpts = 8 eps = 0.55  The average silhouette_score is : 0.35351151917691337
# For minpts = 8 eps = 0.6  The average silhouette_score is : 0.3514007702376851
# For minpts = 8 eps = 0.65  The average silhouette_score is : 0.3563422043915
# For minpts = 8 eps = 0.7  The average silhouette_score is : 0.3557060723283559
# For minpts = 8 eps = 0.75  The average silhouette_score is : 0.3565649417421008
# For minpts = 9 eps = 0.5  The average silhouette_score is : 0.3473264710148699
# For minpts = 9 eps = 0.55  The average silhouette_score is : 0.35200448872014023
# For minpts = 9 eps = 0.6  The average silhouette_score is : 0.3529654179364104
# For minpts = 9 eps = 0.65  The average silhouette_score is : 0.3563422043915
# For minpts = 9 eps = 0.7  The average silhouette_score is : 0.3557060723283559
# For minpts = 9 eps = 0.75  The average silhouette_score is : 0.3557060723283559
# For minpts = 10 eps = 0.5  The average silhouette_score is : 0.3466216538848452
# For minpts = 10 eps = 0.55  The average silhouette_score is : 0.3482549296101841
# For minpts = 10 eps = 0.6  The average silhouette_score is : 0.3529654179364104
# For minpts = 10 eps = 0.65  The average silhouette_score is : 0.355085518926691
# For minpts = 10 eps = 0.7  The average silhouette_score is : 0.3550028138971601
# For minpts = 10 eps = 0.75  The average silhouette_score is : 0.3557060723283559
# For minpts = 11 eps = 0.5  The average silhouette_score is : 0.3469736782934782
# For minpts = 11 eps = 0.55  The average silhouette_score is : 0.34912853787904136
# For minpts = 11 eps = 0.6  The average silhouette_score is : 0.3522518720413736
# For minpts = 11 eps = 0.65  The average silhouette_score is : 0.3536275079899411
# For minpts = 11 eps = 0.7  The average silhouette_score is : 0.3540942822528557
# For minpts = 11 eps = 0.75  The average silhouette_score is : 0.3550028138971601
# For minpts = 12 eps = 0.5  The average silhouette_score is : 0.3473270427650204
# For minpts = 12 eps = 0.55  The average silhouette_score is : 0.3471876286300233
# For minpts = 12 eps = 0.6  The average silhouette_score is : 0.35078526987158176
# For minpts = 12 eps = 0.65  The average silhouette_score is : 0.35290005279427017
# For minpts = 12 eps = 0.7  The average silhouette_score is : 0.3521695062279914
# For minpts = 12 eps = 0.75  The average silhouette_score is : 0.3550028138971601
# For minpts = 13 eps = 0.5  The average silhouette_score is : 0.34597762161515266
# For minpts = 13 eps = 0.55  The average silhouette_score is : 0.3460175080777119
# For minpts = 13 eps = 0.6  The average silhouette_score is : 0.35078526987158176
# For minpts = 13 eps = 0.65  The average silhouette_score is : 0.35247667740372823
# For minpts = 13 eps = 0.7  The average silhouette_score is : 0.3521695062279914
# For minpts = 13 eps = 0.75  The average silhouette_score is : 0.3540942822528557
# For minpts = 14 eps = 0.5  The average silhouette_score is : 0.346467441309974
# For minpts = 14 eps = 0.55  The average silhouette_score is : 0.34658011247108683
# For minpts = 14 eps = 0.6  The average silhouette_score is : 0.3514316008357746
# For minpts = 14 eps = 0.65  The average silhouette_score is : 0.3506593895001425
# For minpts = 14 eps = 0.7  The average silhouette_score is : 0.35302889306574536
# For minpts = 14 eps = 0.75  The average silhouette_score is : 0.35443427096664143
# Text(0.5,1,'Silhouette Score ')

# %% [markdown]
# The best clustering, according to silhouette score, is for eps = 0.65 and minpts = 9. This gave a silhouette score of 0.3563.

# %%
from mpl_toolkits.mplot3d import Axes3D


clustering = DBSCAN(eps=0.65, min_samples=9)
clustering.fit(anthony_data)
clusters = clustering.labels_

fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
p = ax.scatter(anthony_data[:,0],
               anthony_data[:, 1],
               anthony_data[:,2],
              alpha = 0.3,
              c=clusters)

ax.set_xlim3d(-1,3)
#ax.set_ylim3d(1,6)
#ax.set_zlim3d(4,9)
# Out:
# (-1, 3)

# %%
n_clusters_ = len(set(clusters)) - (1 if -1 in clusters else 0)
plt.scatter(anthony_data[:,0],
            anthony_data[:, 1],
            c = clusters,
           alpha = 0.5)
plt.xlabel('log(recency)')
plt.ylabel('frequency')
plt.title(len(set(clusters)))
# Out:
# Text(0.5,1,'3')

# %%
plt.scatter(anthony_data[:,0],
            anthony_data[:, 2],
            c = clusters)

# %% [markdown]
# DBScan seems to create 3 clusters based heavily on frequency of purchase. One cluster seems to only have a few points in it, and they do not appear strongly correlated with one another. As can be seen in the 3-D plot however, all of these points lay distinctly outside of the other clusters. These are our noise points.

# %% [markdown]
# ### Agglomerative Clustering

# %%
for n_clust in range(2,10):
    for link in ['ward', 'complete', 'average']:
        clustering2 = AgglomerativeClustering(n_clusters =n_clust, 
                                        linkage = link)
        clustering2.fit(anthony_data)
        clusters2 = clustering2.labels_
        print('n_clusters =', n_clust,
              '; linkage =', link, 
              '; Silhouette score =',silhouette_score(anthony_data, clusters2))
# Out:
# n_clusters = 2 ; linkage = ward ; Silhouette score = 0.3842924414048734
# n_clusters = 2 ; linkage = complete ; Silhouette score = 0.3645621247167768
# n_clusters = 2 ; linkage = average ; Silhouette score = 0.6076227214160238
# n_clusters = 3 ; linkage = ward ; Silhouette score = 0.3894943178312267
# n_clusters = 3 ; linkage = complete ; Silhouette score = 0.22779655509672886
# n_clusters = 3 ; linkage = average ; Silhouette score = 0.4943072946107462
# n_clusters = 4 ; linkage = ward ; Silhouette score = 0.31259587404786837
# n_clusters = 4 ; linkage = complete ; Silhouette score = 0.1994266228337823
# n_clusters = 4 ; linkage = average ; Silhouette score = 0.35389714134028
# n_clusters = 5 ; linkage = ward ; Silhouette score = 0.31112393358130436
# n_clusters = 5 ; linkage = complete ; Silhouette score = 0.19832132435342678
# n_clusters = 5 ; linkage = average ; Silhouette score = 0.30525713126077236
# n_clusters = 6 ; linkage = ward ; Silhouette score = 0.2873765078154817
# n_clusters = 6 ; linkage = complete ; Silhouette score = 0.25393691987155065
# n_clusters = 6 ; linkage = average ; Silhouette score = 0.2953554417458724
# n_clusters = 7 ; linkage = ward ; Silhouette score = 0.2884906306991183
# n_clusters = 7 ; linkage = complete ; Silhouette score = 0.25209336459470066
# n_clusters = 7 ; linkage = average ; Silhouette score = 0.26105811405293317
# n_clusters = 8 ; linkage = ward ; Silhouette score = 0.25361482685423387
# n_clusters = 8 ; linkage = complete ; Silhouette score = 0.23844590874887697
# n_clusters = 8 ; linkage = average ; Silhouette score = 0.2296361550489103
# n_clusters = 9 ; linkage = ward ; Silhouette score = 0.23160710803955759
# n_clusters = 9 ; linkage = complete ; Silhouette score = 0.1632296770110595
# n_clusters = 9 ; linkage = average ; Silhouette score = 0.29763533500480027

# %% [markdown]
# Agglomerative clustering yields a slightly different result from DBSCAN. The best clustering, according to silhouette score, is for n_clusters = 2 and average linkage. Let's look at this result more carefully.

# %%
clustering2 = AgglomerativeClustering(n_clusters =2, 
                                linkage = 'average')
clustering2.fit(anthony_data)
clusters2 = clustering2.labels_
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
p = ax.scatter(anthony_data[:,0],
               anthony_data[:, 1],
               anthony_data[:,2],
              alpha = 0.04,
              c=clusters2)
ax.set_xlim3d(-1,3)
# Out:
# (-1, 3)

# %%
plt.scatter(anthony_data[:,0],
            anthony_data[:, 1],
            c = clusters2)
plt.xlabel('log(recency)')
plt.ylabel('frequency')
# Out:
# Text(0,0.5,'frequency')

# %%
plt.scatter(anthony_data[:,0],
            anthony_data[:, 2],
            c = clusters2)

# %%
clustering3 = AgglomerativeClustering(n_clusters =3, 
                                linkage = 'average')
clustering3.fit(anthony_data)
clusters3 = clustering3.labels_
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
p = ax.scatter(anthony_data[:,0],
               anthony_data[:, 1],
               anthony_data[:,2],
              alpha = 0.04,
              c=clusters3)
ax.set_xlim3d(-1,3)
# Out:
# (-1, 3)

# %%
plt.scatter(anthony_data[:,0],
            anthony_data[:, 1],
            c = clusters3,
           alpha = 0.5)
plt.xlabel('log(recency)')
plt.ylabel('frequency')
# Out:
# Text(0,0.5,'frequency')

# %%
plt.scatter(as_data[:,0],
            as_data[:, 2],
            c = clusters3)

# %% [markdown]
# These clustering parameters yield 3 clusters. 2 of them contain 1 point each, and the third is the rest of the data. These clusters are not very meaningful except to identify these 2 outliers.
#
# We will therefore look at the third best agglomerative clustering result, n_clusters = 3, with Ward linkage.

# %%
clustering4 = AgglomerativeClustering(n_clusters =3, 
                                linkage = 'ward')
clustering4.fit(anthony_data)
clusters4 = clustering4.labels_
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
p = ax.scatter(anthony_data[:,0],
               anthony_data[:, 1],
               anthony_data[:,2],
              alpha = 0.04,
              c=clusters4)
ax.set_xlim3d(-1,3)
# Out:
# (-1, 3)

# %%
plt.scatter(anthony_data[:,0],
            anthony_data[:, 1],
            c = clusters4,
           alpha = 0.5)
plt.xlabel('log(recency)')
plt.ylabel('frequency')
# Out:
# Text(0,0.5,'frequency')

# %%
plt.scatter(anthony_data[:,0],
            anthony_data[:, 2],
            c = clusters4,
            alpha = 0.5)
plt.xlabel('log(recency)')
plt.ylabel('log(Monetary Value)')
# Out:
# Text(0,0.5,'log(Monetary Value)')

# %% [markdown]
# This looks like a real clustering result!
# - The first cluster (yellow) is characterized by frequent, recent buyers. They also typically buy less than the average buyer.
# - The second cluster (purple) is less frequent spenders that recently purchased goods. They typically spend around the average amount of money.
# - The third cluster (green) is buyers that have not recently bought. They typically buy less frequently, but they spend more money that the average customer.
